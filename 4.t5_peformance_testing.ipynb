# %%
#from bert_score import score
from rouge import Rouge
import os 
#import torch
from datetime import datetime
import openpyxl
import pandas as pd
import re

# %%
input_dir = "./Data/Generation/"
generated_column = "automatic_text"
target_column =  "original_text"    
results_path = "./Data/Results/{}.xlsx".format(datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# %%
model_name_lst = []
rouge_1_p_lst = []
rouge_1_r_lst = []
rouge_1_f_lst = []
rouge_2_p_lst = []
rouge_2_r_lst = []
rouge_2_f_lst = []
rouge_l_p_lst = []
rouge_l_r_lst = []
rouge_l_f_lst = []

rouge = Rouge()
for df in os.listdir(input_dir):
    if (df != ".ipynb_checkpoints"): 
       
        data = pd.read_csv(input_dir + df)
        data = data[data[target_column]!=""]
        
        if  type(data[generated_column].to_list()[0]) == str:
            automatic = data[generated_column].to_list()
        else:
            automatic = [sentence[0] for sentence in data[generated_column].to_list()]
            

        gold = data[target_column].to_list()
        scores = rouge.get_scores(automatic , gold, avg=True)


        model_name_lst.append(df)
        rouge_1_p_lst.append(scores["rouge-1"]["p"])
        rouge_1_r_lst.append(scores["rouge-1"]["r"])
        rouge_1_f_lst.append(scores["rouge-1"]["f"])
        rouge_2_p_lst.append(scores["rouge-2"]["p"])
        rouge_2_r_lst.append(scores["rouge-2"]["r"])
        rouge_2_f_lst.append(scores["rouge-2"]["f"])
        rouge_l_p_lst.append(scores["rouge-l"]["p"])
        rouge_l_r_lst.append(scores["rouge-l"]["r"])
        rouge_l_f_lst.append(scores["rouge-l"]["f"])

    
result_df = pd.DataFrame(
            {    
                'model': model_name_lst,
                'rouge-1_f_score': rouge_1_f_lst,
                'rouge-2_f_score': rouge_2_f_lst,
                'rouge-l_f_score':  rouge_l_f_lst,
                
                'rouge-1_precision': rouge_1_p_lst,
                'rouge-2_precision': rouge_2_p_lst,
                'rouge-l_precision': rouge_l_p_lst,
                
                'rouge-1_recall':  rouge_1_r_lst,
                'rouge-2_recall': rouge_2_r_lst,
                'rouge-l_recall':  rouge_l_r_lst,
                
            }
      )
result_df.to_excel(results_path)

# %%
pd.set_option('display.max_colwidth', -1) # 11
result_df
# Out:
# /var/tmp/pbs.3357255.cerit-pbs.cerit-sc.cz/ipykernel_143853/2496648838.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1) # 11
#                                                          model  \
# 0  generated_d-t5-t5-base-grammar-correction_grammar_added.csv
# 1  generated_d-t5-fine_tunned_large.csv
# 2  generated_d-t5-t5-base-grammar-correction.csv
# 3  generated_d-t5-fine_tunned_base.csv
# 4  generated_d-t5-fine_tunned_3b.csv
#
#    rouge-1_f_score  rouge-2_f_score  rouge-l_f_score  rouge-1_precision  \
# 0  0.691641         0.514188         0.668965         0.739405
# 1  0.684530         0.508413         0.663190         0.755522
# 2  0.689002         0.505343         0.665376         0.738626
# 3  0.680921         0.495270         0.658621         0.730360
# 4  0.551484         0.362065         0.535976         0.720098
#
#    rouge-2_precision  rouge-l_precision  rouge-1_recall  rouge-2_recall  \
# 0  0.555482           0.714628           0.655821        0.483504
# 1  0.572235           0.731431           0.635943        0.465652
# 2  0.548662           0.712933           0.652140        0.473718
# 3  0.539241           0.705910           0.643469        0.462700
# 4  0.492402           0.698838           0.457076        0.294667
#
#    rouge-l_recall
# 0  0.634723
# 1  0.616367
# 2  0.630061
# 3  0.622795
# 4  0.444643
